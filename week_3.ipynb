# %% [markdown]
# <a href="https://colab.research.google.com/github/Joshan2005/Petroleum-Data-Analytics/blob/main/week_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# creating a series using range()
import pandas as pd
ser1=pd.Series(range(5,15))
print(ser1)
# Out:
# 0     5
# 1     6
# 2     7
# 3     8
# 4     9
# 5    10
# 6    11
# 7    12
# 8    13
# 9    14
# dtype: int64

# %%
# creating dataframe from series
ser2=pd.DataFrame(ser1)
print(ser2)
# Out:
#     0
# 0   5
# 1   6
# 2   7
# 3   8
# 4   9
# 5  10
# 6  11
# 7  12
# 8  13
# 9  14

# %%
# creating dataframe from dictionaries
import pandas as pd
dict = {'Porosity':[1,2,3,4],'Permeability':[10,20,30,40],'Density':[100,200,300,400]}
ser3=pd.DataFrame(dict)
print(ser3)
# Out:
#    Porosity  Permeability  Density
# 0         1            10      100
# 1         2            20      200
# 2         3            30      300
# 3         4            40      400

# %%
# creating dataframes
import pandas as pd
ser4=pd.DataFrame({'Solvent':['DMP','NMP','DMSO','THF'],'Solubility':[50,90,85,20],'Boiling Point':[178,192,202,36]})
print(ser4)
# Out:
#   Solvent  Solubility  Boiling Point
# 0     DMP          50            178
# 1     NMP          90            192
# 2    DMSO          85            202
# 3     THF          20             36

# %%
# retrieve first few elements
ser4.head(2)
# Out:
#   Solvent  Solubility  Boiling Point
# 0     DMP          50            178
# 1     NMP          90            192

# %%
# retrieving a partiular columns
ser5 = ser4[['Solvent','Solubility']]
ser5
# Out:
#   Solvent  Solubility
# 0     DMP          50
# 1     NMP          90
# 2    DMSO          85
# 3     THF          20

# %%
# filter observations with logical operations
ser4[ser4.Solubility<=50]
# Out:
#   Solvent  Solubility  Boiling Point
# 0     DMP          50            178
# 3     THF          20             36

# %%
# range() function

for i in range(6):
  print(i,end="")
  print()

for i in range(0,10,2):
  print(i,end="")
  print()
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 0
# 2
# 4
# 6
# 8

# %%
# printing random
import random

num=random.random()
print(num)

list4=[1,2,3,4,5,6,7,8,9]
print(random.choice(list4))

name = 'joshan'
print(random.choice(name))

# print(random.)
# Out:
# 0.37712876511425997
# 1
# a
